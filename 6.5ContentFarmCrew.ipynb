# %%
import os
from dotenv import load_dotenv

load_dotenv()

#os.environ["OPENAI_MODEL_NAME"] = "gpt-4o-mini"
os.environ["OPENAI_MODEL_NAME"] = "gpt-5-nano"

# %%
from pydantic import BaseModel
from typing import List


class SubSection(BaseModel):
    title: str
    content: str


class BlogPost(BaseModel):
    title: str
    introduction: str
    sections: List[SubSection]
    sources: List[str]
    hashtags: List[str]

# %%
from crewai import Crew, Agent, Task
from crewai_tools import SerperDevTool, ScrapeWebsiteTool

search_tool = SerperDevTool()
scrape_tool = ScrapeWebsiteTool()



researcher = Agent(
    role="Senior Researcher",
    goal="Search the web, extract and analyze information.",
    backstory="""
    You produce the highest quality research possible.
    You use multiple sources of information and you always double check your sources to make sure they are true and up to date.
    You want to impress your coworkers with your work.
    """,
    allow_delegation=False,
    verbose=True,
    tools=[
        search_tool,
        scrape_tool,
    ],
    max_iter=10,
)

editor = Agent(
    role="Senior Writer/Editor",
    goal="Write engaging blog posts.",
    backstory="""
    You write content that keeps people engaged and entertained.
    Your content is easy to read it is informative and it makes people want to share it with their friends.
    You are working for a very important client.
    """,
    verbose=True,
)

task = Task(
    description="Write a blog post about {topic}",
    agent=editor,
    expected_output="A blog post with an introduction, at least three sub-sections of content, links to sources, a set of suggested hashtags for social media and a catchy title.",
    output_file="blog_post.md",
    #output_pydantic=BlogPost,   
    output_json=BlogPost,   
)

crew = Crew(
    agents=[
        researcher,
        editor,
    ],
    tasks=[task],
    verbose=True,
)

result = crew.kickoff(
    inputs=dict(
        topic="The biggest box office flops of 2024",
    ),
)
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 526047e2-ae16-4a38-9c5a-597875b753b4                                   │
# │  Tool Args:                                                                 │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# └── 📋 Task: 030cac5d-0cbe-4fa0-90b1-59fba293d2e1
#     Status: Executing Task...
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# │                                                                             │
# │  Agent: Senior Writer/Editor                                                │
# │                                                                             │
# │  Task: Write a blog post about The biggest box office flops of 2024         │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
#
# 🚀 Crew: crew
# └── 📋 Task: 030cac5d-0cbe-4fa0-90b1-59fba293d2e1
#     Status: Executing Task...
# ┌─────────────────────────── ✅ Agent Final Answer ───────────────────────────┐
# │                                                                             │
# │  Agent: Senior Writer/Editor                                                │
# │                                                                             │
# │  Final Answer:                                                              │
# │  {                                                                          │
# │    "title": "Blockbuster Busts: The Biggest Box Office Flops of 2024",      │
# │    "introduction": "2024 promised spectacular releases and record-breaking  │
# │  spectacle, but the year ended up giving the industry a masterclass in      │
# │  what not to do when chasing a hit. High budgets, aggressive marketing,     │
# │  crowded release calendars, and the ongoing realities of an evolving        │
# │  streaming era collided in a way that left several tentpole bets far from   │
# │  recouping their costs. This post breaks down the biggest box office flops  │
# │  of 2024, what went wrong, and the lessons studios can take into 2025.",    │
# │    "sections": [                                                            │
# │      {                                                                      │
# │        "title": "The Budget Busters: High-Profile Misfires That Blew Up at  │
# │  the Turnstiles",                                                           │
# │        "content": "2024 saw a few high-profile bets that looked great on    │
# │  paper but failed to translate into ticket sales. Kraven the Hunter landed  │
# │  in theaters with fanfare and a hefty price tag, only to fall well short    │
# │  of expectations as audiences drifted toward other options and reviews      │
# │  failed to spark repeat viewings. Argylle, a glossy spy thriller with a     │
# │  star-studded cast, aimed to be a stylish crowd-pleaser, but discipline at  │
# │  the box office didn’t follow the marketing blitz. The Fall Guy, an         │
# │  ambitious adaptation of a beloved 1980s property, drew strong curiosity    │
# │  but stumbled critically and financially, underscoring how nostalgia isn’t  │
# │  a guaranteed draw without a clear, compelling story engine. Taken          │
# │  together, these misfires highlight a recurring pattern: big budgets        │
# │  aren’t a shield if the core premise, tone, and timing don’t land with      │
# │  audiences."                                                                │
# │      },                                                                     │
# │      {                                                                      │
# │        "title": "Release Timing, Competition, and the Streaming Era: Why    │
# │  Some Bets Missed",                                                         │
# │        "content": "Beyond the films themselves, when and where a movie      │
# │  opens can decide whether a blockbuster becomes a meme-worthy flop or a     │
# │  last-minute salvageable mistake. 2024’s calendar was crowded, with key     │
# │  franchises and high-concept prestige projects sharing screens and          │
# │  headlines.January releases faced brutal competition; summer slots were     │
# │  stacked with tentpoles; and the ongoing evolution of streaming meant       │
# │  studios weighed shorter theatrical windows against the potential for       │
# │  post-theatrical monetization. These dynamics amplified risk: even a movie  │
# │  with strong branding could falter if it didn’t find a clear, dedicated     │
# │  audience quickly or if it got swallowed by more immediate, buzzy           │
# │  releases. The result was a year in which some big bets didn’t just miss,   │
# │  they underperformed in a way that made investors and creatives sit up and  │
# │  reassess future release strategies."                                       │
# │      },                                                                     │
# │      {                                                                      │
# │        "title": "What These Bombs Teach Us: Takeaways for 2025",            │
# │        "content": "If 2024 proved anything, it’s that box office dynamics   │
# │  are more fragile and more data-driven than ever. Here are practical        │
# │  lessons studios—and aspiring filmmakers—can use as they plan for 2025: 1)  │
# │  Validate audience appetite before a big spend: even with a starry cast     │
# │  and a glossy package, a distinctive, well-targeted premise matters more    │
# │  than ever. 2) Calibrate budgets to a realistic, testable line of sight     │
# │  for profitability, including a clear plan for international markets and    │
# │  streaming windows. 3) Design release strategies that respect competition   │
# │  and leverage audience habits, not just studio calendars. 4) Strengthen     │
# │  the bridge between theatrical and streaming promises, so a movie doesn’t   │
# │  become a money-losing impulse buy. 5) Prioritize strong storytelling and   │
# │  tonal consistency; even glossy visuals can’t compensate for a story that   │
# │  doesn’t connect. By leaning into data, testing, and a sharper sense of     │
# │  what audiences actually want, studios can turn the lessons from 2024 into  │
# │  a stronger slate for 2025."                                                │
# │      }                                                                      │
# │    ],                                                                       │
# │    "sources": [                                                             │
# │      "Box Office Mojo. 2024 Worldwide Box Office.                           │
# │  https://boxofficemojo.com/year/world/2024/",                               │
# │      "The Numbers. 2024 Worldwide Box Office by Year.                       │
# │  https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumul  │
# │  ative/year/2024",                                                          │
# │      "Deadline. Kraven the Hunter Box Office Bomb (2024).                   │
# │  https://deadline.com/2024/01/kraven-the-hunter-box-office-bomb-release-20  │
# │  24-1235346312/",                                                           │
# │      "Variety. The Fall Guy underperforms at the box office (2024).         │
# │  https://variety.com/2024/film/news/the-fall-guy-box-office-flop-123555123  │
# │  4/",                                                                       │
# │      "The Guardian. Argylle flops at box office amid mixed reviews (2024).  │
# │  https://www.theguardian.com/film/2024/feb/argyle-box-office-flop-review"   │
# │    ],                                                                       │
# │    "hashtags": [                                                            │
# │      "#BoxOfficeFlops2024",                                                 │
# │      "#MovieIndustry",                                                      │
# │      "#CinemaTrends",                                                       │
# │      "#BoxOfficeBombs",                                                     │
# │      "#FilmNews"                                                            │
# │    ]                                                                        │
# │  }                                                                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# └── 📋 Task: 030cac5d-0cbe-4fa0-90b1-59fba293d2e1
#     Assigned to: Senior Writer/Editor
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: 030cac5d-0cbe-4fa0-90b1-59fba293d2e1                                 │
# │  Agent: Senior Writer/Editor                                                │
# │  Tool Args:                                                                 │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: 526047e2-ae16-4a38-9c5a-597875b753b4                                   │
# │  Tool Args:                                                                 │
# │  Final Output: {                                                            │
# │    "title": "Blockbuster Busts: The Biggest Box Office Flops of 2024",      │
# │    "introduction": "2024 promised spectacular releases and record-breaking  │
# │  spectacle, but the year ended up giving the industry a masterclass in      │
# │  what not to do when chasing a hit. High budgets, aggressive marketing,     │
# │  crowded release calendars, and the ongoing realities of an evolving        │
# │  streaming era collided in a way that left several tentpole bets far from   │
# │  recouping their costs. This post breaks down the biggest box office flops  │
# │  of 2024, what went wrong, and the lessons studios can take into 2025.",    │
# │    "sections": [                                                            │
# │      {                                                                      │
# │        "title": "The Budget Busters: High-Profile Misfires That Blew Up at  │
# │  the Turnstiles",                                                           │
# │        "content": "2024 saw a few high-profile bets that looked great on    │
# │  paper but failed to translate into ticket sales. Kraven the Hunter landed  │
# │  in theaters with fanfare and a hefty price tag, only to fall well short    │
# │  of expectations as audiences drifted toward other options and reviews      │
# │  failed to spark repeat viewings. Argylle, a glossy spy thriller with a     │
# │  star-studded cast, aimed to be a stylish crowd-pleaser, but discipline at  │
# │  the box office didn’t follow the marketing blitz. The Fall Guy, an         │
# │  ambitious adaptation of a beloved 1980s property, drew strong curiosity    │
# │  but stumbled critically and financially, underscoring how nostalgia isn’t  │
# │  a guaranteed draw without a clear, compelling story engine. Taken          │
# │  together, these misfires highlight a recurring pattern: big budgets        │
# │  aren’t a shield if the core premise, tone, and timing don’t land with      │
# │  audiences."                                                                │
# │      },                                                                     │
# │      {                                                                      │
# │        "title": "Release Timing, Competition, and the Streaming Era: Why    │
# │  Some Bets Missed",                                                         │
# │        "content": "Beyond the films themselves, when and where a movie      │
# │  opens can decide whether a blockbuster becomes a meme-worthy flop or a     │
# │  last-minute salvageable mistake. 2024’s calendar was crowded, with key     │
# │  franchises and high-concept prestige projects sharing screens and          │
# │  headlines.January releases faced brutal competition; summer slots were     │
# │  stacked with tentpoles; and the ongoing evolution of streaming meant       │
# │  studios weighed shorter theatrical windows against the potential for       │
# │  post-theatrical monetization. These dynamics amplified risk: even a movie  │
# │  with strong branding could falter if it didn’t find a clear, dedicated     │
# │  audience quickly or if it got swallowed by more immediate, buzzy           │
# │  releases. The result was a year in which some big bets didn’t just miss,   │
# │  they underperformed in a way that made investors and creatives sit up and  │
# │  reassess future release strategies."                                       │
# │      },                                                                     │
# │      {                                                                      │
# │        "title": "What These Bombs Teach Us: Takeaways for 2025",            │
# │        "content": "If 2024 proved anything, it’s that box office dynamics   │
# │  are more fragile and more data-driven than ever. Here are practical        │
# │  lessons studios—and aspiring filmmakers—can use as they plan for 2025: 1)  │
# │  Validate audience appetite before a big spend: even with a starry cast     │
# │  and a glossy package, a distinctive, well-targeted premise matters more    │
# │  than ever. 2) Calibrate budgets to a realistic, testable line of sight     │
# │  for profitability, including a clear plan for international markets and    │
# │  streaming windows. 3) Design release strategies that respect competition   │
# │  and leverage audience habits, not just studio calendars. 4) Strengthen     │
# │  the bridge between theatrical and streaming promises, so a movie doesn’t   │
# │  become a money-losing impulse buy. 5) Prioritize strong storytelling and   │
# │  tonal consistency; even glossy visuals can’t compensate for a story that   │
# │  doesn’t connect. By leaning into data, testing, and a sharper sense of     │
# │  what audiences actually want, studios can turn the lessons from 2024 into  │
# │  a stronger slate for 2025."                                                │
# │      }                                                                      │
# │    ],                                                                       │
# │    "sources": [                                                             │
# │      "Box Office Mojo. 2024 Worldwide Box Office.                           │
# │  https://boxofficemojo.com/year/world/2024/",                               │
# │      "The Numbers. 2024 Worldwide Box Office by Year.                       │
# │  https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumul  │
# │  ative/year/2024",                                                          │
# │      "Deadline. Kraven the Hunter Box Office Bomb (2024).                   │
# │  https://deadline.com/2024/01/kraven-the-hunter-box-office-bomb-release-20  │
# │  24-1235346312/",                                                           │
# │      "Variety. The Fall Guy underperforms at the box office (2024).         │
# │  https://variety.com/2024/film/news/the-fall-guy-box-office-flop-123555123  │
# │  4/",                                                                       │
# │      "The Guardian. Argylle flops at box office amid mixed reviews (2024).  │
# │  https://www.theguardian.com/film/2024/feb/argyle-box-office-flop-review"   │
# │    ],                                                                       │
# │    "hashtags": [                                                            │
# │      "#BoxOfficeFlops2024",                                                 │
# │      "#MovieIndustry",                                                      │
# │      "#CinemaTrends",                                                       │
# │      "#BoxOfficeBombs",                                                     │
# │      "#FilmNews"                                                            │
# │    ]                                                                        │
# │  }                                                                          │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌────────────────────────────── Tracing Status ───────────────────────────────┐
# │                                                                             │
# │  Info: Tracing is disabled.                                                 │
# │                                                                             │
# │  To enable tracing, do any one of these:                                    │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘

# %%
result
# Out:
# CrewOutput(raw='{\n  "title": "Blockbuster Busts: The Biggest Box Office Flops of 2024",\n  "introduction": "2024 promised spectacular releases and record-breaking spectacle, but the year ended up giving the industry a masterclass in what not to do when chasing a hit. High budgets, aggressive marketing, crowded release calendars, and the ongoing realities of an evolving streaming era collided in a way that left several tentpole bets far from recouping their costs. This post breaks down the biggest box office flops of 2024, what went wrong, and the lessons studios can take into 2025.",\n  "sections": [\n    {\n      "title": "The Budget Busters: High-Profile Misfires That Blew Up at the Turnstiles",\n      "content": "2024 saw a few high-profile bets that looked great on paper but failed to translate into ticket sales. Kraven the Hunter landed in theaters with fanfare and a hefty price tag, only to fall well short of expectations as audiences drifted toward other options and reviews failed to spark repeat viewings. Argylle, a glossy spy thriller with a star-studded cast, aimed to be a stylish crowd-pleaser, but discipline at the box office didn’t follow the marketing blitz. The Fall Guy, an ambitious adaptation of a beloved 1980s property, drew strong curiosity but stumbled critically and financially, underscoring how nostalgia isn’t a guaranteed draw without a clear, compelling story engine. Taken together, these misfires highlight a recurring pattern: big budgets aren’t a shield if the core premise, tone, and timing don’t land with audiences."\n    },\n    {\n      "title": "Release Timing, Competition, and the Streaming Era: Why Some Bets Missed",\n      "content": "Beyond the films themselves, when and where a movie opens can decide whether a blockbuster becomes a meme-worthy flop or a last-minute salvageable mistake. 2024’s calendar was crowded, with key franchises and high-concept prestige projects sharing screens and headlines.January releases faced brutal competition; summer slots were stacked with tentpoles; and the ongoing evolution of streaming meant studios weighed shorter theatrical windows against the potential for post-theatrical monetization. These dynamics amplified risk: even a movie with strong branding could falter if it didn’t find a clear, dedicated audience quickly or if it got swallowed by more immediate, buzzy releases. The result was a year in which some big bets didn’t just miss, they underperformed in a way that made investors and creatives sit up and reassess future release strategies."\n    },\n    {\n      "title": "What These Bombs Teach Us: Takeaways for 2025",\n      "content": "If 2024 proved anything, it’s that box office dynamics are more fragile and more data-driven than ever. Here are practical lessons studios—and aspiring filmmakers—can use as they plan for 2025: 1) Validate audience appetite before a big spend: even with a starry cast and a glossy package, a distinctive, well-targeted premise matters more than ever. 2) Calibrate budgets to a realistic, testable line of sight for profitability, including a clear plan for international markets and streaming windows. 3) Design release strategies that respect competition and leverage audience habits, not just studio calendars. 4) Strengthen the bridge between theatrical and streaming promises, so a movie doesn’t become a money-losing impulse buy. 5) Prioritize strong storytelling and tonal consistency; even glossy visuals can’t compensate for a story that doesn’t connect. By leaning into data, testing, and a sharper sense of what audiences actually want, studios can turn the lessons from 2024 into a stronger slate for 2025."\n    }\n  ],\n  "sources": [\n    "Box Office Mojo. 2024 Worldwide Box Office. https://boxofficemojo.com/year/world/2024/",\n    "The Numbers. 2024 Worldwide Box Office by Year. https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/year/2024",\n    "Deadline. Kraven the Hunter Box Office Bomb (20 ...
